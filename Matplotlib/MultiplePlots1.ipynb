# %%
# Multiplots in Python using Matplotlib
# The Stacked plots
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,10,0.01)

plt.subplot(3,1,1)
plt.plot(x,np.sin(x))

plt.subplot(3,1,2)
plt.plot(x,np.cos(x))

plt.subplot(3,1,3)
plt.plot(x,x)

plt.show()

# %%
# Grid Plots
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,10,0.01)
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,x)

plt.subplot(2,2,4)
plt.plot(x,5-x)

plt.show()

# %%
# Overlap plot
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
x = np.arange(0,10,0.01)
plt.plot(x,x-5)

plt.title("Not so Tiny")
fig.add_subplot(2,2,4)
plt.plot(x,5-x)

plt.title("Tiny plot")
plt.show()

# %%
# Three digit format for passing arguments
import matplotlib.pyplot as plt
import numpy as np
 
 
x = np.arange(0, 10, 0.01)
plt.subplot(221)
plt.plot(x, np.sin(x))
 
plt.subplot(222)
plt.plot(x, np.cos(x))
 
plt.subplot(223)
plt.plot(x, x)
 
plt.subplot(224)
plt.plot(x, 5-x)
plt.show()
